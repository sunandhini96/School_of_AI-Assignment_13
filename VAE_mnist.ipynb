# %% [markdown]
# <a href="https://colab.research.google.com/github/sunandhini96/School_of_AI-Assignment_13/blob/main/VAE_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Lambda, Input, Dense
from keras.models import Model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
import numpy as np
from keras.optimizers import Adam
import matplotlib.pyplot as plt

(x_train_data, y_train_data), (x_test_data, y_test_data) = mnist.load_data()
image_size = x_train_data.shape[1]
original_dim = image_size * image_size
x_train_data = np.reshape(x_train_data, [-1, original_dim])
x_test_data = np.reshape(x_test_data, [-1, original_dim])
x_train_data = x_train_data.astype('float32') / 255.0
x_test_data = x_test_data.astype('float32') / 255.0
input_shape = (original_dim, )
batch_size = 128

def latent_sampling(args):
    z_mean_layer, z_log_var_layer = args
    batch = K.shape(z_mean_layer)[0]
    dimension = K.int_shape(z_mean_layer)[1]
    ep = K.random_normal(shape=(batch, dimension))
    return z_mean_layer + K.exp(0.5 * z_log_var_layer) * ep

def create_model(hidden_node, latent_node):
    # build encoder model
    # input layer
    encoder_inputs = Input(shape=input_shape, name='input_encoder')
    # hidden layer
    encoder_hidden = Dense(hidden_node, activation='relu')(encoder_inputs)

    z_mean = Dense(latent_node, name='z_mean')(encoder_hidden)
    z_log_var = Dense(latent_node, name='z_log_var')(encoder_hidden)

    # normalize log variance to std dev
    z = Lambda(latent_sampling, output_shape=(latent_node,), name='z')([z_mean, z_log_var])

    # instantiate encoder model
    encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')
    encoder.summary()

    # build decoder model
    latent_encoder_inputs = Input(shape=(latent_node,), name='latent_sampling')
    decoder_hidden = Dense(hidden_node, activation='relu')(latent_encoder_inputs)
    decoder_outputs = Dense(original_dim, activation='sigmoid')(decoder_hidden)

    # instantiate decoder model
    decoder = Model(latent_encoder_inputs, decoder_outputs, name='decoder')
    decoder.summary()

    # instantiate VAE model
    model_outputs = decoder(encoder(encoder_inputs)[2])
    vae = Model(encoder_inputs, model_outputs, name='vae_mlp')
    
    reconstruction_loss = binary_crossentropy(encoder_inputs, model_outputs)
    reconstruction_loss *= original_dim
    kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
    kl_loss = K.sum(kl_loss, axis=-1)
    kl_loss *= -0.5
    vae_loss = K.mean(reconstruction_loss + kl_loss)
    vae.add_loss(vae_loss)
    vae.compile(optimizer=Adam(learning_rate=0.001))

    # vae.compile(optimizer='adam')
    #vae.summary()
    return vae, encoder, decoder

def train_model(model):
    trained_model = model.fit(x_train_data, epochs=epochs,
                batch_size=batch_size,
                validation_data=(x_test_data, None))
    return trained_model 

def plot_latent_space(encoder):
    z_test, _, _ = encoder.predict(x_test_data, batch_size=batch_size)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_test[:, 0], z_test[:, 1], c=y_test_data)
    plt.colorbar()
    plt.xlabel("Z[0]")
    plt.ylabel("Z[1]")
    plt.savefig("VAE")
    plt.show()

def plot_vae_output(decoder,latent_dim):
    n = 20
    digit_num = 28
    figure = np.zeros((digit_num * n, digit_num * n))
    axis_x = np.linspace(-3, 3, n)
    axis_y = np.linspace(-3, 3, n)[::-1]    
    for i, yi in enumerate(axis_y):
        for j, xi in enumerate(axis_x):
            if(latent_dim == 2):
                latent_sample = np.array([[xi, yi]*int(latent_dim/2)])
            else:
                latent_sample = np.random.normal(0,1,size=[batch_size, latent_dim])
            input_decoded = decoder.predict(latent_sample)
            digit = input_decoded[0].reshape(digit_num, digit_num)
            figure[i * digit_num: (i + 1) * digit_num,
                   j * digit_num: (j + 1) * digit_num] = digit
    
    plt.figure(figsize=(10, 10))
    i_range = digit_num // 2
    j_range = (n - 1) * digit_num + i_range + 1
    pixel_range = np.arange(i_range, j_range, digit_num)
    sample_range_x = np.round(axis_x, 1)
    sample_range_y = np.round(axis_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.imshow(figure, cmap='Greens_r')
    plt.savefig("VAE_Output")
    plt.show()

#Create VAE model with 2 code units and generating images by varying each code unit from -3 to 3
intermediate_dim = 256
latent_dim = 16
epochs = 50
vae, encoder, decoder = create_model(intermediate_dim, latent_dim)
trained_model = train_model(vae)
plot_latent_space(encoder)
plot_vae_output(decoder, latent_dim)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_encoder (InputLayer)     [(None, 784)]        0           []
#
#  dense_49 (Dense)               (None, 256)          200960      ['input_encoder[0][0]']
#
#  z_mean (Dense)                 (None, 16)           4112        ['dense_49[0][0]']
#
#  z_log_var (Dense)              (None, 16)           4112        ['dense_49[0][0]']
#
#  z (Lambda)                     (None, 16)           0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 209,184
# Trainable params: 209,184
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  latent_sampling (InputLayer  [(None, 16)]             0
#  )
#
#  dense_50 (Dense)            (None, 256)               4352
#
#  dense_51 (Dense)            (None, 784)               201488
#
# =================================================================
# Total params: 205,840
# Trainable params: 205,840
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 11s 21ms/step - loss: 171.3216 - val_loss: 133.0307
# Epoch 2/50
# 469/469 [==============================] - 9s 19ms/step - loss: 127.1764 - val_loss: 121.0776
# Epoch 3/50
# 469/469 [==============================] - 10s 21ms/step - loss: 119.8234 - val_loss: 116.2965
# Epoch 4/50
# 469/469 [==============================] - 10s 21ms/step - loss: 116.1698 - val_loss: 113.5731
# Epoch 5/50
# 469/469 [==============================] - 9s 20ms/step - loss: 113.9100 - val_loss: 112.0653
# Epoch 6/50
# 469/469 [==============================] - 11s 23ms/step - loss: 112.3982 - val_loss: 110.6948
# Epoch 7/50
# 469/469 [==============================] - 10s 21ms/step - loss: 111.2292 - val_loss: 109.6785
# Epoch 8/50
# 469/469 [==============================] - 9s 19ms/step - loss: 104.5348 - val_loss: 104.2717
# Epoch 35/50
# 469/469 [==============================] - 10s 21ms/step - loss: 104.5045 - val_loss: 104.3053
# Epoch 36/50
# 469/469 [==============================] - 10s 21ms/step - loss: 104.3997 - val_loss: 104.2630
# Epoch 37/50
# 469/469 [==============================] - 9s 18ms/step - loss: 104.3604 - val_loss: 104.2317
# Epoch 38/50
# 469/469 [==============================] - 10s 21ms/step - loss: 104.3284 - val_loss: 104.1831
# Epoch 39/50
# 469/469 [==============================] - 10s 21ms/step - loss: 104.2220 - val_loss: 104.0923
# Epoch 40/50
# 469/469 [==============================] - 9s 19ms/step - loss: 104.1685 - val_loss: 104.0215
# Epoch 41/50
# 469/469 [==============================] - 9s 20ms/step - loss: 104.1108 - val_loss: 104.0843
# Epoch 42/50
# 469/469 [==============================] - 12s 25ms/step - loss: 104.0506 - val_loss: 103.8428
# Epoch 43/50
# 469/469 [==============================] - 10s 21ms/step - loss: 103.9787 - val_loss: 103.9487
# Epoch 44/50
# 469/469 [==============================] - 9s 20ms/step - loss: 103.9321 - val_loss: 103.9826
# Epoch 45/50
# 469/469 [==============================] - 9s 19ms/step - loss: 103.8879 - val_loss: 103.8005
# Epoch 46/50
# 469/469 [==============================] - 10s 21ms/step - loss: 103.8617 - val_loss: 103.8302
# Epoch 47/50
# 469/469 [==============================] - 10s 21ms/step - loss: 103.7509 - val_loss: 103.7477
# Epoch 48/50
# 469/469 [==============================] - 9s 18ms/step - loss: 103.6915 - val_loss: 103.7383
# Epoch 49/50
# 469/469 [==============================] - 10s 21ms/step - loss: 103.6996 - val_loss: 103.6179
# Epoch 50/50
# 469/469 [==============================] - 10s 21ms/step - loss: 103.6288 - val_loss: 103.6087
# 79/79 [==============================] - 125s 4ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 4ms/step

# %%
# Choose 25 random indices from the test set
num_samples = 25
indices = np.random.choice(range(len(x_test_data)), num_samples, replace=False)

# Generate wrong label codes
wrong_labels = np.random.randint(0, 10, num_samples)
for i in range(num_samples):
    while wrong_labels[i] == y_test_data[indices[i]]:
        wrong_labels[i] = np.random.randint(0, 10)

# Generate images with wrong labels
latent_samples, _, _ = encoder.predict(x_test_data[indices], batch_size=batch_size)
latent_samples[:, 0] = wrong_labels  # replace first dimension with wrong label codes
generated_images = decoder.predict(latent_samples)

# Plot the generated images
n = 5
fig, axs = plt.subplots(nrows=n, ncols=n, figsize=(10, 10))
for i in range(n*n):
    row = i // n
    col = i % n
    axs[row, col].imshow(generated_images[i].reshape(28, 28), cmap='gray')
    axs[row, col].axis('off')
    axs[row, col].set_title('True label: {}\nGenerated label: {}'.format(y_test_data[indices[i]], wrong_labels[i]))
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 61ms/step
